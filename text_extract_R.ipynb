# %%
library(pdftools)
pdf_file <- "html_google_scholar/papers/1.pdf"
txt <- pdf_text(pdf_file)
# Out:
# Warning message:
# "package 'pdftools' was built under R version 3.6.3"Using poppler version 0.73.0

# %%
cat(txt)
# Out:
#                                                                                 Subscriber access provided by University of Kansas Libraries
# C: Energy Conversion and Storage; Energy and Charge Transport
# Microstructural Modeling of Composite Cathodes for All-Solid-State Batteries
#                                Anja Bielefeld, Dominik A. Weber, and Jürgen Janek
#     J. Phys. Chem. C, Just Accepted Manuscript • DOI: 10.1021/acs.jpcc.8b11043 • Publication Date (Web): 31 Dec 2018
#                                  Downloaded from http://pubs.acs.org on January 5, 2019
#      Just Accepted
#        “Just Accepted” manuscripts have been peer-reviewed and accepted for publication. They are posted
#        online prior to technical editing, formatting for publication and author proofing. The American Chemical
#        Society provides “Just Accepted” as a service to the research community to expedite the dissemination
# ...
